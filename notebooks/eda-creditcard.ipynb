# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cc = pd.read_csv("../data/raw/creditcard.csv")

# %%
cc['Class'].value_counts(normalize=True)
fraud = cc[cc['Class'] == 1]
non_fraud = cc[cc['Class'] == 0].sample(n=len(fraud)*5, random_state=42)
fraud = pd.concat([fraud, non_fraud]).reset_index(drop=True)
fraud.shape
# Out:
# (2952, 31)

# %%
sns.boxplot(x='Class', y='Amount', data=cc)
plt.show()
